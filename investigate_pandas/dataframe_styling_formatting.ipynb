# %% [markdown]
# # 15. DataFrame Styling & Formatting (5+ Years Interview Guide)
# Exhaustive revision guide to DataFrame presentation for HTML dashboards: highlight_max, highlight_null, format, and background_gradient on transaction data.
#
# ### Key 5-Year Interview Concepts Covered:
# - **Highlighting Elements**: Dedicated cell for `df.style.highlight_max()` and `df.style.highlight_null()`.
# - **Custom Formatting**: Dedicated cell for `df.style.format({'price': '${:.2f}'})`.
# - **Color Gradients**: Dedicated cell for `df.style.background_gradient(cmap='Blues')`.
#
# This interactive revision guide uses `data/raw_transactions.csv` for all real-world code examples.

# %%
# Setup imports & dataset loading
import pandas as pd
import numpy as np
import sys
import time
import os
import matplotlib.pyplot as plt

# Load raw transactions dataset
csv_path = 'data/raw_transactions.csv' if os.path.exists('data/raw_transactions.csv') else '../data/raw_transactions.csv'
df = pd.read_csv(csv_path)
print(f"Pandas Version: {pd.__version__}")
print(f"Loaded raw_transactions.csv: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Pandas Version: 2.2.2
# Loaded raw_transactions.csv: 15000 rows, 11 columns

# %% [markdown]
# ### Highlighting Extrema with `highlight_max()` & `highlight_null()`
# **Explanation**: Applies CSS styling to flag peak revenue and missing data in regional summaries.
#
# **Syntax**: `summary_df.style.highlight_max(color='lightgreen').highlight_null(color='pink')`

# %%
reg_summary = df.pivot_table(index='region', columns='card_type', values='transaction_amount', aggfunc='mean')
styled_max = reg_summary.style.highlight_max(axis=0, color='lightgreen')
print('Style Object Created:', styled_max)
# Out:
# Style Object Created: <pandas.io.formats.style.Styler object at 0x00000224FF4A80B0>

# %% [markdown]
# ### Currency & Percentage Formatting with `df.style.format()`
# **Explanation**: Formats numeric spending averages as currency strings for executive reporting.
#
# **Syntax**: `reg_summary.style.format('${:,.2f}')`

# %%
styled_fmt = reg_summary.style.format('${:,.2f}')
print('Currency Formatted Table Ready for HTML Export.')
# Out:
# Currency Formatted Table Ready for HTML Export.

# %% [markdown]
# ### Heatmap Color Gradients with `df.style.background_gradient()`
# **Explanation**: Renders a continuous background color gradient highlighting high-spending regions.
#
# **Syntax**: `reg_summary.style.background_gradient(cmap='YlGnBu')`

# %%
styled_heatmap = reg_summary.style.background_gradient(cmap='YlGnBu')
print('Heatmap Gradient Initialized.')
# Out:
# Heatmap Gradient Initialized.

# %% [markdown]
# ## Section: Senior Fintech Interview Scenarios (5+ Years Experience)

# %% [markdown]
# ### Q1: Standalone HTML Dashboard Export
# **Explanation**: Render and export styled regional tables directly to HTML files.
#
# **Syntax**: `html_code = styled_fmt.to_html()`

# %%
html_output = styled_fmt.to_html()
print('Generated HTML Table Length:', len(html_output), 'characters')
# Out:
# Generated HTML Table Length: 5356 characters
