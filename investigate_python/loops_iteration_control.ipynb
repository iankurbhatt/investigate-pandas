# %% [markdown]
# # Loops & Iteration Control (5+ Years Interview Guide)
# Exhaustive revision guide with dedicated separate cells for for-loops, range, while-loops, break, continue, and for/while...else on raw_transactions.csv.
#
# ### Key 5-Year Interview Concepts Covered:
# - **For-Loop Iteration**: Dedicated separate cell for `for item in iterable:`.
# - **Range Progression**: Dedicated separate cells for `range(stop)` and `range(start, stop, step)`.
# - **While-Loop Execution**: Dedicated separate cell for `while condition:`.
# - **Flow Interruption**: Dedicated separate cells for `break` and `continue`.
# - **Fallback Clauses**: Dedicated separate cells for `for ... else:` and `while ... else:`.
#
# This interactive revision guide uses `data/raw_transactions.csv` with 1-to-1 atomic method cells.

# %%
# Setup imports & dataset loading from raw_transactions.csv
import csv
import sys
import time
import os

csv_path = 'data/raw_transactions.csv' if os.path.exists('data/raw_transactions.csv') else '../data/raw_transactions.csv'
transactions = []
with open(csv_path, mode='r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        transactions.append(row)

print(f"Python Version: {sys.version.split()[0]}")
print(f"Loaded {len(transactions)} transaction records from {csv_path}")
print('Sample Record:', transactions[0])
# Out:
# Python Version: 3.12.7
# Loaded 15000 transaction records from data/raw_transactions.csv
# Sample Record: {'transaction_id': 'TX110686', 'customer_id': 'C82845', 'merchant_id': 'M2697', 'transaction_amount': '1216.33', 'card_type': 'Visa', 'transaction_status': 'Failed', 'device_type': 'POS', 'account_age_months': '56', 'transaction_date': '07-06-2025', 'region': 'North', 'is_fraud': '0'}

# %% [markdown]
# ### For-Loop Iteration: `for item in iterable:`
# **Explanation**: Iterates sequentially across elements using Python's underlying iterator protocol.
#
# **Syntax**: `for item in seq:`

# %%
for t in transactions[:3]:
    print(f'Processing {t["transaction_id"]}: ${float(t["transaction_amount"]):.2f}')
# Out:
# Processing TX110686: $1216.33
# Processing TX107170: $324.99
# Processing TX108328: $136.66

# %% [markdown]
# ### Sequence Generation: `range(stop)`
# **Explanation**: Generates integer sequence from 0 to `stop - 1` with $O(1)$ constant memory.
#
# **Syntax**: `range(5)`

# %%
for i in range(3):
    print(f'Iteration Index {i}: {transactions[i]["transaction_id"]}')
# Out:
# Iteration Index 0: TX110686
# Iteration Index 1: TX107170
# Iteration Index 2: TX108328

# %% [markdown]
# ### Stepped Sequence Generation: `range(start, stop, step)`
# **Explanation**: Generates stepped progressions skipping intermediate indices.
#
# **Syntax**: `range(0, 10, 2)`

# %%
for i in range(0, 6, 2):
    print(f'Stepped Offset {i}: {transactions[i]["transaction_id"]}')
# Out:
# Stepped Offset 0: TX110686
# Stepped Offset 2: TX108328
# Stepped Offset 4: TX107002

# %% [markdown]
# ### While-Loop Execution: `while condition:`
# **Explanation**: Repeats execution dynamically while a state predicate evaluates to True.
#
# **Syntax**: `while count < threshold:`

# %%
count = 0
while count < 3:
    print(f'While Count {count}: {transactions[count]["transaction_id"]}')
    count += 1
# Out:
# While Count 0: TX110686
# While Count 1: TX107170
# While Count 2: TX108328

# %% [markdown]
# ### Loop Interruption: `break`
# **Explanation**: Terminates loop execution immediately upon hitting trigger condition.
#
# **Syntax**: `if cond: break`

# %%
for t in transactions:
    if int(t['is_fraud']) == 1:
        print(f'First Fraud Intercepted: {t["transaction_id"]}. Breaking loop!')
        break
# Out:
# First Fraud Intercepted: TX110960. Breaking loop!

# %% [markdown]
# ### Loop Skipping: `continue`
# **Explanation**: Skips remainder of current iteration and moves immediately to next item.
#
# **Syntax**: `if cond: continue`

# %%
for t in transactions[:5]:
    if float(t['transaction_amount']) < 500.0:
        continue
    print(f'High-Value Transaction: {t["transaction_id"]} (${float(t["transaction_amount"]):.2f})')
# Out:
# High-Value Transaction: TX110686 ($1216.33)
# High-Value Transaction: TX107002 ($1284.68)

# %% [markdown]
# ### For-Loop Fallback Clause: `for ... else:`
# **Explanation**: `else:` block executes ONLY if loop completes naturally without encountering a `break`.
#
# **Syntax**: `for item in seq: ... else: ...`

# %%
search_id = 'NON_EXISTENT_TX'
for t in transactions[:5]:
    if t['transaction_id'] == search_id:
        print('Found!')
        break
else:
    print(f'Search ID {search_id} not found (for...else executed).')
# Out:
# Search ID NON_EXISTENT_TX not found (for...else executed).

# %% [markdown]
# ### While-Loop Fallback Clause: `while ... else:`
# **Explanation**: `else:` block executes when while condition becomes False (and loop was not terminated by break).
#
# **Syntax**: `while cond: ... else: ...`

# %%
n = 0
while n < 2:
    n += 1
else:
    print('While condition completed cleanly (while...else executed).')
# Out:
# While condition completed cleanly (while...else executed).

# %% [markdown]
# ## Section: Senior Fintech Interview Scenarios (5+ Years Experience)

# %% [markdown]
# ### Q1: Memory Optimization: Python `range` vs `list(range)`
# **Explanation**: Explain why `range` objects consume only 48 bytes regardless of span size ($O(1)$ memory).
#
# **Syntax**: `sys.getsizeof(range(1000000))`

# %%
print('Size of range(0, 10_000_000):', sys.getsizeof(range(0, 10_000_000)), 'bytes')
print('Size of list(range(100)):', sys.getsizeof(list(range(100))), 'bytes')
# Out:
# Size of range(0, 10_000_000): 48 bytes
# Size of list(range(100)): 856 bytes
