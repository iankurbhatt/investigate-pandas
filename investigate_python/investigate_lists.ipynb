# %% [markdown]
# # 06. Python Lists & Operations
# Exhaustive guide to list indexing, slicing, extensions, copy levels, searches, dynamic capacities overallocation, and list comprehensions.
#
# This notebook uses the shared Fintech dataset `data/raw_transactions.csv` for combined analysis questions at the end.

# %%
# Setup: Locate the Shared Dataset
import os
csv_path = 'data/raw_transactions.csv' if os.path.exists('data/raw_transactions.csv') else '../data/raw_transactions.csv'
print("Using CSV file path:", csv_path)
# Out:
# Using CSV file path: ../data/raw_transactions.csv

# %% [markdown]
# ### 1. What is a List?
# **Explanation**: Mutable, ordered collection sequence arrays.
#
# **Syntax**:
# ```python
# list_variable = [value_one, value_two]
# ```

# %%
card_providers_list = ['Visa', 'MasterCard']
print(card_providers_list)
# Out:
# ['Visa', 'MasterCard']

# %% [markdown]
# ### 2. Positive index lookups
# **Explanation**: Access items using 0-based indices.
#
# **Syntax**:
# ```python
# list_variable[index]
# ```

# %%
card_providers_list = ['Visa', 'MasterCard']
print(card_providers_list[0])
# Out:
# Visa

# %% [markdown]
# ### 3. Negative index reverse lookups
# **Explanation**: Access items starting from end.
#
# **Syntax**:
# ```python
# list_variable[-index]
# ```

# %%
card_providers_list = ['Visa', 'MasterCard']
print(card_providers_list[-1])
# Out:
# MasterCard

# %% [markdown]
# ### 4. Basic slices boundaries
# **Explanation**: Slices lists subsets.
#
# **Syntax**:
# ```python
# list_variable[start:stop]
# ```

# %%
transaction_amounts_list = [10.0, 20.0, 30.0]
print(transaction_amounts_list[1:3])
# Out:
# [20.0, 30.0]

# %% [markdown]
# ### 5. Slice steps increments
# **Explanation**: Slices using custom steps.
#
# **Syntax**:
# ```python
# list_variable[start:stop:step]
# ```

# %%
transaction_amounts_list = [10.0, 20.0, 30.0, 40.0]
print(transaction_amounts_list[::2])
# Out:
# [10.0, 30.0]

# %% [markdown]
# ### 6. Reversing lists via slicing
# **Explanation**: Reverse list sequences.
#
# **Syntax**:
# ```python
# list_variable[::-1]
# ```

# %%
transaction_amounts_list = [10.0, 20.0, 30.0]
print(transaction_amounts_list[::-1])
# Out:
# [30.0, 20.0, 10.0]

# %% [markdown]
# ### 7. Adding items to lists
# **Explanation**: Insert or append elements.
#
# **Syntax**:
# ```python
# list_variable.append(value)
# list_variable.insert(index, value)
# ```

# %%
mutable_limits_list = [100.0]
mutable_limits_list.append(200.0)
mutable_limits_list.insert(0, 50.0)
print(mutable_limits_list)
# Out:
# [50.0, 100.0, 200.0]

# %% [markdown]
# ### 8. Concatenating lists sequences
# **Explanation**: Extends lists in-place.
#
# **Syntax**:
# ```python
# list_variable.extend(iterable_object)
# ```

# %%
mutable_limits_list = [100.0]
mutable_limits_list.extend([200.0, 300.0])
print(mutable_limits_list)
# Out:
# [100.0, 200.0, 300.0]

# %% [markdown]
# ### 9. Deleting list items
# **Explanation**: Remove elements by value or index.
#
# **Syntax**:
# ```python
# list_variable.remove(value)
# list_variable.pop(index)
# ```

# %%
mutable_limits_list = [100.0, 200.0]
mutable_limits_list.remove(100.0)
popped_value = mutable_limits_list.pop()
print(mutable_limits_list, popped_value)
# Out:
# [] 200.0

# %% [markdown]
# ### 10. Sorting and Reversing order
# **Explanation**: Sorts or reverses lists in-place.
#
# **Syntax**:
# ```python
# list_variable.sort()
# list_variable.reverse()
# ```

# %%
mutable_limits_list = [300.0, 100.0]
mutable_limits_list.sort()
print(mutable_limits_list)
# Out:
# [100.0, 300.0]

# %% [markdown]
# ### 11. Shallow copies of lists
# **Explanation**: Shallow copying copies references only.
#
# **Syntax**:
# ```python
# copied_list = list_variable.copy()
# copied_list = list_variable[:]
# ```
#
# **Visual Explanation (Data with Baraa Style)**:
# ```mermaid
# graph TD
#     orig[nested_list] --> container([Outer List Reference])
#     copy[shallow_copied_list] --> container_c([New Outer List Reference])
#     container --> inner([Inner List: 100.0])
#     container_c --> inner
#     style inner fill:#f9f,stroke:#333,stroke-width:2px
# ```

# %%
nested_list = [[100.0]]
shallow_copied_list = nested_list.copy()
shallow_copied_list[0].append(200.0)
print('shallow:', shallow_copied_list, '| original:', nested_list)
# Out:
# shallow: [[100.0, 200.0]] | original: [[100.0, 200.0]]

# %% [markdown]
# ### 12. Deep copies of lists
# **Explanation**: Deep copy copies nested structures recursively.
#
# **Syntax**:
# ```python
# import copy
# deeply_copied_list = copy.deepcopy(list_variable)
# ```
#
# **Visual Explanation (Data with Baraa Style)**:
# ```mermaid
# graph TD
#     orig[nested_list] --> container([Outer List Reference])
#     copy[deeply_copied_list] --> container_c([New Outer List Reference])
#     container --> inner([Inner List: 100.0])
#     container_c --> inner_c([New Inner List: 100.0])
#     style inner fill:#f9f,stroke:#333,stroke-width:2px
#     style inner_c fill:#aaf,stroke:#333,stroke-width:2px
# ```

# %%
import copy
nested_list = [[100.0]]
deeply_copied_list = copy.deepcopy(nested_list)
deeply_copied_list[0].append(200.0)
print('deeply:', deeply_copied_list, '| original:', nested_list)
# Out:
# deeply: [[100.0, 200.0]] | original: [[100.0]]

# %% [markdown]
# ### 13. List element search and counts
# **Explanation**: Find item indexes and counts.
#
# **Syntax**:
# ```python
# list_variable.index(value)
# list_variable.count(value)
# ```

# %%
amounts_list = [10.0, 20.0, 20.0]
print('Index of 20.0:', amounts_list.index(20.0), 'Count:', amounts_list.count(20.0))
# Out:
# Index of 20.0: 1 Count: 2

# %% [markdown]
# ### 14. List multiplication replication
# **Explanation**: Replicates list items.
#
# **Syntax**:
# ```python
# list_variable * multiplier_value
# ```

# %%
base_list = [1.0]
print(base_list * 3)
# Out:
# [1.0, 1.0, 1.0]

# %% [markdown]
# ### 15. Membership checks
# **Explanation**: Checks item containment.
#
# **Syntax**:
# ```python
# value in list_variable
# ```

# %%
allowed_cards_list = ['Visa']
print('Visa' in allowed_cards_list)
# Out:
# True

# %% [markdown]
# ### 16. Multi-dimensional nested lists
# **Explanation**: Lists nested inside lists.
#
# **Syntax**:
# ```python
# nested_matrix_list = [[value_one, value_two]]
# ```

# %%
nested_matrix_list = [[100.0, 200.0]]
print(nested_matrix_list[0][1])
# Out:
# 200.0

# %% [markdown]
# ### 17. List comprehensions basics
# **Explanation**: Syntactic generators to construct list objects.
#
# **Syntax**:
# ```python
# [expression for item in iterable]
# ```

# %%
squares_payouts_list = [x**2 for x in range(3)]
print(squares_payouts_list)
# Out:
# [0, 1, 4]

# %% [markdown]
# ### 18. List comprehensions with filters
# **Explanation**: Filter values in comprehensions.
#
# **Syntax**:
# ```python
# [expression for item in iterable if condition]
# ```

# %%
filtered_evens_list = [x for x in range(5) if x%2==0]
print(filtered_evens_list)
# Out:
# [0, 2, 4]

# %% [markdown]
# ### 19. Nested list comprehensions
# **Explanation**: Comprehend nested loops.
#
# **Syntax**:
# ```python
# [inner_item for outer_item in matrix for inner_item in outer_item]
# ```

# %%
nested_matrix = [[1], [2]]
flattened_list = [y for x in nested_matrix for y in x]
print(flattened_list)
# Out:
# [1, 2]

# %% [markdown]
# ### 20. List conversions from iterables
# **Explanation**: Cast objects to lists.
#
# **Syntax**:
# ```python
# list(iterable_object)
# ```

# %%
converted_string_list = list('abc')
print(converted_string_list)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ## Section 3: Fintech Interview Questions
#
# ### Q1: Extract transaction status values from the first 20 rows, count 'Completed' entries, and search for the index of the first 'Failed' entry.

# %%
# Solution:
status_list = []
with open(csv_path, 'r') as f:
    f.readline()
    for _ in range(20):
        row = f.readline().strip().split(',')
        status_list.append(row[5])
        
completed_count = status_list.count('Completed')
try:
    failed_index = status_list.index('Failed')
except ValueError:
    failed_index = -1
print('Completed counts:', completed_count, '| First Failed Index:', failed_index)
# Out:
# Completed counts: 8 | First Failed Index: 0

# %% [markdown]
# ### Q2: Create a deep copy of a list of transaction details parsed from the first 3 rows to show reference isolation.

# %%
# Solution:
import copy
tx_details = []
with open(csv_path, 'r') as f:
    f.readline()
    for _ in range(3):
        row = f.readline().strip().split(',')
        tx_details.append([row[0], row[3]])
        
details_copy = copy.deepcopy(tx_details)
details_copy[0][1] = '0.00'
print('Original:', tx_details[0])
print('Modified Copy:', details_copy[0])
# Out:
# Original: ['TX110686', '1216.33']
# Modified Copy: ['TX110686', '0.00']
