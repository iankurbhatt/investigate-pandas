# %% [markdown]
# # 13. File Handling, Stream I/O & Pathlib: Beginner Guide
#
# ### 📌 Overview & Architectural Context
# Welcome to **13. File Handling, Stream I/O & Pathlib**. Modern Python replaces legacy string path manipulation (`os.path`) with the object-oriented `pathlib.Path` API. This notebook covers stream file access modes (`r`, `w`, `a`, `rb`, `wb`), buffering controls, in-memory I/O streams (`io.StringIO`, `io.BytesIO`), and directory tree walking via `Path.glob()` and `Path.rglob()`.
#
# ### 📚 Key Concepts Covered in this Notebook:
# - [x] 🔹 Stream Opening: Read Mode `'r'`
# - [x] 🔹 Stream Opening: Write Mode `'w'`
# - [x] 🔹 Stream Opening: Append Mode `'a'`
# - [x] 🔹 Stream Opening: Binary Mode `'rb'` & `'wb'`
# - [x] 🔹 Context Management: `with open(...) as f:`
# - [x] 🔹 Data Reading: `.read()`
# - [x] 🔹 Data Reading: `.readline()`
# - [x] 🔹 Data Reading: `.readlines()`
# - [x] 🔹 Data Writing: `.write()`
# - [x] 🔹 Data Writing: `.writelines()`
# - [x] 🔹 Stream Positioning: `.tell()`
# - [x] 🔹 Stream Positioning: `.seek()`
# - [x] 🔹 Stream Buffer: `.flush()`

# %%
# Setup imports & dataset loading from raw_transactions.csv
import csv
import sys
import time
import os

csv_path = 'data/raw_transactions.csv' if os.path.exists('data/raw_transactions.csv') else '../data/raw_transactions.csv'
transactions = []
with open(csv_path, mode='r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        transactions.append(row)

print(f"Python Version: {sys.version.split()[0]}")
print(f"Loaded {len(transactions)} transaction records from {csv_path}")
# Out:
# Python Version: 3.12.7
# Loaded 15000 transaction records from ../data/raw_transactions.csv

# %% [markdown]
# ### 🔹 Stream Opening: Read Mode `'r'`
# - **What it does:** Opens an existing text file for sequential reading.
# - **Syntax:** `'r'`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Opening with practical fintech data structures and variables in the following code block.

# %%
f = open(csv_path, mode='r', encoding='utf-8')
first_line = f.readline().strip()
f.close()
print('Read Mode First Line:', first_line)
# Out:
# Read Mode First Line: transaction_id,customer_id,merchant_id,transaction_amount,card_type,transaction_status,device_type,account_age_months,transaction_date,region,is_fraud

# %% [markdown]
# ### 🔹 Stream Opening: Write Mode `'w'`
# - **What it does:** Creates a new file for writing, truncating/overwriting any existing content.
# - **Syntax:** `'w'`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Opening with practical fintech data structures and variables in the following code block.

# %%
os.makedirs('scratch', exist_ok=True)
with open('scratch/demo_write.txt', mode='w', encoding='utf-8') as f:
    f.write('TX_AUDIT_LOG_START\n')
print('Write mode file created.')
# Out:
# Write mode file created.

# %% [markdown]
# ### 🔹 Stream Opening: Append Mode `'a'`
# - **What it does:** Opens file for appending data to end without truncating existing content.
# - **Syntax:** `'a'`
#   - **Parameters:**
#     - `item` (*object*): Element to add to the end of the list.
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Opening with practical fintech data structures and variables in the following code block.

# %%
with open('scratch/demo_write.txt', mode='a', encoding='utf-8') as f:
    f.write('TX_LOG_ENTRY_2\n')
print('Append mode written.')
# Out:
# Append mode written.

# %% [markdown]
# ### 🔹 Stream Opening: Binary Mode `'rb'` & `'wb'`
# - **What it does:** Reads and writes raw unencoded bytes directly to and from disk.
# - **Syntax:** `'rb'`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Opening with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='rb') as f:
    raw_bytes = f.read(30)
print('Read 30 raw binary bytes:', raw_bytes)
# Out:
# Read 30 raw binary bytes: b'transaction_id,customer_id,mer'

# %% [markdown]
# ### 🔹 Context Management: `with open(...) as f:`
# - **What it does:** Ensures deterministic stream closure via `__exit__` even upon unhandled exceptions.
# - **Syntax:** `with open(...) as f:`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Context Management with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='r', encoding='utf-8') as f:
    header = f.readline().strip()
print('Opened securely via context manager:', header)
# Out:
# Opened securely via context manager: transaction_id,customer_id,merchant_id,transaction_amount,card_type,transaction_status,device_type,account_age_months,transaction_date,region,is_fraud

# %% [markdown]
# ### 🔹 Data Reading: `.read()`
# - **What it does:** Reads entire file (or up to `size` characters) into a single string.
# - **Syntax:** `.read()`
#   - **Parameters:**
#     - `row_label` (*hashable*): Row label.
#     - `col_label` (*hashable*): Column label.
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Data Reading with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='r', encoding='utf-8') as f:
    chunk = f.read(80)
print('Read 80 characters:', repr(chunk))
# Out:
# Read 80 characters: 'transaction_id,customer_id,merchant_id,transaction_amount,card_type,transaction_'

# %% [markdown]
# ### 🔹 Data Reading: `.readline()`
# - **What it does:** Reads next single line including trailing newline `\n`.
# - **Syntax:** `.readline()`
#   - **Parameters:**
#     - `row_label` (*hashable*): Row label.
#     - `col_label` (*hashable*): Column label.
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Data Reading with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='r', encoding='utf-8') as f:
    print('Line 1:', f.readline().strip())
    print('Line 2:', f.readline().strip())
# Out:
# Line 1: transaction_id,customer_id,merchant_id,transaction_amount,card_type,transaction_status,device_type,account_age_months,transaction_date,region,is_fraud
# Line 2: TX109326,C55082,M3549,607.78,Visa,Reversed,Mobile,8,2026-02-17 08:28:57,North,0

# %% [markdown]
# ### 🔹 Data Reading: `.readlines()`
# - **What it does:** Reads all remaining lines into a list of strings.
# - **Syntax:** `.readlines()`
#   - **Parameters:**
#     - `row_label` (*hashable*): Row label.
#     - `col_label` (*hashable*): Column label.
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Data Reading with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='r', encoding='utf-8') as f:
    f.readline() # Skip header
    top3_lines = [f.readline().strip() for _ in range(3)]
print('Read 3 lines:', top3_lines)
# Out:
# Read 3 lines: ['TX109326,C55082,M3549,607.78,Visa,Reversed,Mobile,8,2026-02-17 08:28:57,North,0', 'TX106376,C76616,M3068,1819.11,Visa,Pending,POS,28,03-Jan-2025,West,1', 'TX103301,C65296,M3352,64.08,Visa,Completed,Mobile,91,20-Dec-2025,East,0']

# %% [markdown]
# ### 🔹 Data Writing: `.write()`
# - **What it does:** Writes string data into output stream buffer.
# - **Syntax:** `.write()`
#   - **Parameters:**
#     - `row_label` (*hashable*): Row label.
#     - `col_label` (*hashable*): Column label.
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Applies Data Writing on fintech records using columns `transaction_amount`, `transaction_id` to demonstrate real-world execution.

# %%
with open('scratch/demo_write.txt', mode='w', encoding='utf-8') as f:
    bytes_written = f.write(f"{transactions[0]['transaction_id']},{transactions[0]['transaction_amount']}\n")
print('Bytes written:', bytes_written)
# Out:
# Bytes written: 16

# %% [markdown]
# ### 🔹 Data Writing: `.writelines()`
# - **What it does:** Writes an iterable sequence of strings to disk without automatically adding newlines.
# - **Syntax:** `.writelines()`
#   - **Parameters:**
#     - `row_label` (*hashable*): Row label.
#     - `col_label` (*hashable*): Column label.
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Applies Data Writing on fintech records using columns `transaction_id` to demonstrate real-world execution.

# %%
lines_to_write = [f"{t['transaction_id']}\n" for t in transactions[:3]]
with open('scratch/demo_write.txt', mode='w', encoding='utf-8') as f:
    f.writelines(lines_to_write)
print('Writelines completed.')
# Out:
# Writelines completed.

# %% [markdown]
# ### 🔹 Stream Positioning: `.tell()`
# - **What it does:** Returns current integer byte position offset in file stream.
# - **Syntax:** `.tell()`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Positioning with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='r', encoding='utf-8') as f:
    print('Initial position:', f.tell())
    f.readline()
    print('Position after header line:', f.tell())
# Out:
# Initial position: 0
# Position after header line: 152

# %% [markdown]
# ### 🔹 Stream Positioning: `.seek()`
# - **What it does:** Repositions file stream cursor to specified byte offset (`0` = start).
# - **Syntax:** `.seek()`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Positioning with practical fintech data structures and variables in the following code block.

# %%
with open(csv_path, mode='r', encoding='utf-8') as f:
    f.readline()
    f.seek(0) # Rewind to start
    print('Position after seek(0):', f.tell())
# Out:
# Position after seek(0): 0

# %% [markdown]
# ### 🔹 Stream Buffer: `.flush()`
# - **What it does:** Forces internal memory buffers to write to OS kernel disk cache immediately.
# - **Syntax:** `.flush()`
# - **Key Note:** Print intermediate variables with `print()` or inspect their type with `type()` to trace how data changes at each step.
# - **Dataset Application & Code Demonstration:** Demonstrates Stream Buffer with practical fintech data structures and variables in the following code block.

# %%
with open('scratch/demo_write.txt', mode='w', encoding='utf-8') as f:
    f.write('CRITICAL_TRANSACTION_RECORD\n')
    f.flush()
print('Flushed buffer to OS.')
# Out:
# Flushed buffer to OS.

# %% [markdown]
# ## 💡 Real-World Practice & Scenarios
# Practical scenarios and common data engineering questions explained with real examples.

# %% [markdown]
# ### 🔍 Scenario: Q1: Generator-Based Line Streaming for Out-of-Memory Files
# - **Objective:** Q1: Generator-Based Line Streaming for Out-of-Memory Files
# - **Approach:** Demonstrate constant $O(1)$ memory file streaming using `for line in f:`.
# - **Syntax:** `for line in f: yield parse(line)`

# %%
total_lines = 0
with open(csv_path, mode='r', encoding='utf-8') as f:
    for line in f:
        total_lines += 1
print(f'Streamed {total_lines} lines with O(1) constant RAM footprint.')
# Out:
# Streamed 15001 lines with O(1) constant RAM footprint.
